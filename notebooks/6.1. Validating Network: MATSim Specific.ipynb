# %% [markdown]
# # MatSim specific validation
#
# This page goes through validation checks available in GeNet. Available as a jupyter notebook or wiki page.
#
# You can generate a validation report for the genet Network encompassing validity of the network, schedule and routing (of the transit services in the schedule on the network). It aims to provide a good collection of checks known to have affected MatSim simulations in the past. The report is a simple dictionary with keys: `graph`, `schedule` and `routing`.

# %%
# read sample network
from genet import read_matsim
import os

path_to_matsim_network = '../example_data/pt2matsim_network'

network = os.path.join(path_to_matsim_network, 'network.xml')
schedule = os.path.join(path_to_matsim_network, 'schedule.xml')
vehicles = os.path.join(path_to_matsim_network, 'vehicles.xml')
n = read_matsim(
    path_to_network=network, 
    epsg='epsg:27700', 
    path_to_schedule=schedule, 
    path_to_vehicles=vehicles
)
# you don't need to read the vehicles file, but doing so ensures all vehicles
# in the schedule are of the expected type and the definition of the vehicle
# is preserved
n.print()
# Out:
# Graph info: Name:
# Type: MultiDiGraph
# Number of nodes: 1662
# Number of edges: 3166
# Average in degree:   1.9049
# Average out degree:   1.9049
# Schedule info: Schedule:
# Number of services: 9
# Number of routes: 68
# Number of stops: 118

# %%
report = n.generate_validation_report()
# Out:
# 2022-07-14 16:19:28,787 - Checking validity of the Network
# 2022-07-14 16:19:28,794 - Checking validity of the Network graph
# 2022-07-14 16:19:28,795 - Checking network connectivity for mode: car
# 2022-07-14 16:19:29,009 - Checking network connectivity for mode: walk
# 2022-07-14 16:19:29,027 - Checking network connectivity for mode: bike
# 2022-07-14 16:19:29,436 - Checking validity of the Schedule
# 2022-07-14 16:19:29,514 - 11728 unused vehicles have been found.
# 2022-07-14 16:19:29,546 - No vehicles being used for multiple trips have been found.

# %% [markdown]
# The `graph` section describes strongly connected components of the modal subgraphs, for modes that agents in MATSim need to find routes on: `car`, and `walk` and `bike` if using the `multimodal.contrib`. In addition to this, it also flags links of length 1km or longer that can be inspected separately.

# %%
from pprint import pprint
pprint(report['graph'])
# Out:
# {'graph_connectivity': {'bike': {'number_of_connected_subgraphs': 0,
#                                  'problem_nodes': {'dead_ends': [],
#                                                    'unreachable_node': []}},
#                         'car': {'number_of_connected_subgraphs': 1,
#                                 'problem_nodes': {'dead_ends': [],
#                                                   'unreachable_node': []}},
#                         'walk': {'number_of_connected_subgraphs': 0,
#                                  'problem_nodes': {'dead_ends': [],
#                                                    'unreachable_node': []}}},
#  'link_attributes': {'links_over_1km_length': {'link_ids': [],
#                                                'number_of': 0,
#                                                'percentage': 0.0},
#                      'zero_attributes': {}}}

# %% [markdown]
# The `schedule` section describes correctness of the schedule on three levels:
#
# - `schedule_level`: Overall look at the schedule validity. A `Schedule` is valid if:
#     - all of its' services are valid
#     - its' services are uniquely indexed
#
#     Schedule `has_valid_services` if all services within the schedule are deemed valid. The invalid services are
#     flagged in `invalid_services` and the invalid stages of schedule validity are flagged in `invalid_stages`.
# - `service_level`: Provides a look at validity of services within the schedule. It is indexed by service ids. Each
# `Service` is valid if:
#     - each of its' routes is valid
#     - its' routes are uniquely indexed
#
#     A service `has_valid_routes` if all routes within the service are deemed valid. The invalid routes are
#     flagged in `invalid_routes` and the invalid stages of service validity are flagged in `invalid_stages`.
# - `route_level`: Provides a look at validity of each route within each service indexed by service id and route id
# (or service id and the indexin the `Service.routes` list if not uniquely indexed). Each `Route` is valid if it
#     - has more than one `Stop`
#     - has correctly ordered route (the stops (their link reference ids) and links a route refers to are in the same
#     order)
#     - arrival and departure offsets are correct (each stop has one and they are correctly ordered temporally)
#     - does not have self loops (there are no trips such as: Stop A -> Stop A)
#
#     If a route satisfies the above `is_valid_route` is `True`. If not, the `invalid_stages` flag where the route
#     did not satisfy validity conditions.
#
#     (Nb. The same dictionary can be generated by using `Schedule` object's own `generate_validation_report` method.)
#
# - `vehicle_level`: Looks at the validity of vehicle definitions and their uses. Checks that there is a valid definition for each vehicle, which consists of the following components:
#     - whether any definitions are missing
#     - whether any vehicles are not being used any more
#     - whether any vehicles are being used for multiple trips

# %%
pprint(report['schedule']['schedule_level'])
# Out:
# {'has_valid_services': True,
#  'invalid_services': [],
#  'invalid_stages': [],
#  'is_valid_schedule': True}

# %%
pprint(report['schedule']['service_level']['12430'])
# Out:
# {'has_valid_routes': True,
#  'invalid_routes': [],
#  'invalid_stages': [],
#  'is_valid_service': True}

# %%
pprint(report['schedule']['route_level']['12430'])
# Out:
# {'VJ06420fdab0dfe5c8e7f2f9504df05cf6289cd7d3': {'invalid_stages': [],
#                                                 'is_valid_route': True},
#  'VJ06cd41dcd58d947097df4a8f33234ef423210154': {'invalid_stages': [],
#                                                 'is_valid_route': True},
#  'VJ0f3c08222de16c2e278be0a1bf0f9ea47370774e': {'invalid_stages': [],
#                                                 'is_valid_route': True},
#  'VJ15419796737689e742962a625abcf3fd5b3d58b1': {'invalid_stages': [],
#                                                 'is_valid_route': True},
#  'VJ235c8fca539cf931b3c673f9b056606384aff950': {'invalid_stages': [],
#                                                 'is_valid_route': True},
#  'VJ8f9aea7491080b0137d3092706f53dc11f7dba45': {'invalid_stages': [],
#                                                 'is_valid_route': True},
#  'VJ948e8caa0f08b9c6bf6330927893942c474b5100': {'invalid_stages': [],
#                                                 'is_valid_route': True},
#  'VJ95b4c534d7c903d76ec0340025aa88b81dba3ce4': {'invalid_stages': [],
#                                                 'is_valid_route': True},
#  'VJeae6e634f8479e0b6712780d5728f0afca964e64': {'invalid_stages': [],
#                                                 'is_valid_route': True},
#  'VJeb72539d69ddf8e29f1adf74d43953def196ae41': {'invalid_stages': [],
#                                                 'is_valid_route': True},
#  'VJef7f20c3a9bf1419f6401e1e9131fe2c634bcb9a': {'invalid_stages': [],
#                                                 'is_valid_route': True},
#  'VJf8e38a73359b6cf743d8e35ee64ef1f7b7914daa': {'invalid_stages': [],
#                                                 'is_valid_route': True}}

# %%
pprint(report['schedule']['vehicle_level'])
# Out:
# {'vehicle_definitions_valid': True,
#  'vehicle_definitions_validity_components': {'missing_vehicles': {'missing_vehicles_types': set(),
#                                                                   'vehicles_affected': {}},
#                                              'multiple_use_vehicles': {},
#                                              'unused_vehicles': {'veh_0_bus',
#                                                                  'veh_10000_subway',
#                                                                  'veh_10001_subway',
#                                                                  'veh_10002_subway',
#                                                                  'veh_10003_subway',
#                                                                  'veh_10004_subway',
#                                                                  'veh_10005_subway',
#                                                                  'veh_10006_subway',
#                                                                  'veh_10007_subway',
#                                                                  'veh_10008_subway',
#                                                                  'veh_10009_subway',
#                                                                  'veh_10010_subway',
#                                                                  'veh_10011_subway',
#                                                                  'veh_10012_subway',
#                                                                  'veh_10013_subway',
#                                                                  'veh_10014_subway',
#                                                                  'veh_10015_subway',
#                                                                  'veh_10016_subway',
#                                                                  'veh_10017_subway',
#                                                                  'veh_10018_subway',
#                                                                  'veh_10019_subway',
#                                                                  'veh_10020_subway',
#                                                                  'veh_10021_subway',
#                                                                  'veh_10022_subway',
#                                                                  'veh_10023_subway',
#                                                                  'veh_10024_subway',
#                                                                  'veh_10025_subway',
#                                                                  'veh_10026_subway',
#                                                                  'veh_10027_subway',
#                                                                  'veh_10028_subway',
#                                                                  'veh_10029_subway',
#                                                                  'veh_10030_subway',
#                                                                  'veh_10031_subway',
#                                                                  'veh_10032_subway',
#                                                                  'veh_10033_subway',
#                                                                  'veh_10034_subway',
#                                                                  'veh_10035_subway',
#                                                                  'veh_10036_subway',
#                                                                  'veh_10037_subway',
#                                                                  'veh_10038_subway',
#                                                                  'veh_10039_subway',
#                                                                  'veh_10040_subway',
#                                                                  'veh_10041_subway',
#                                                                  'veh_10042_subway',
#                                                                  'veh_10043_subway',
#                                                                  'veh_10044_subway',
#                                                                  'veh_10045_subway',
#                                                                  'veh_10046_subway',
#                                                                  'veh_10047_subway',
#                                                                  'veh_10048_subway',
#                                                                  'veh_10049_subway',
#                                                                  'veh_10050_subway',
#                                                                  'veh_10051_subway',
#                                                                  'veh_10052_subway',
#                                                                  'veh_10053_subway',
#                                                                  'veh_10054_subway',
#                                                                  'veh_10055_subway',
#                                                                  'veh_10056_subway',
#                                                                  'veh_10057_subway',
#                                                                  'veh_10058_subway',
#                                                                  'veh_10059_subway',
#                                                                  'veh_10060_subway',
#                                                                  'veh_10061_subway',
#                                                                  'veh_10062_subway',
#                                                                  'veh_10063_subway',
#                                                                  'veh_10064_subway',
#                                                                  'veh_10065_subway',
#                                                                  'veh_10066_subway',
#                                                                  'veh_10067_subway',
#                                                                  'veh_10068_subway',
#                                                                  'veh_10069_subway',
#                                                                  'veh_10070_subway',
#                                                                  'veh_10071_subway',
#                                                                  'veh_10072_subway',
#                                                                  'veh_10073_subway',
#                                                                  'veh_10074_subway',
#                                                                  'veh_10075_subway',
#                                                                  'veh_10076_subway',
#                                                                  'veh_10077_subway',
#                                                                  'veh_10078_subway',
#                                                                  'veh_10079_subway',
#                                                                  'veh_10080_subway',
#                                                                  'veh_10081_subway',
#                                                                  'veh_10082_subway',
#                                                                  'veh_10083_subway',
#                                                                  'veh_10084_subway',
#                                                                  'veh_10085_subway',
#                                                                  'veh_10086_subway',
#                                                                  'veh_10087_subway',
#                                                                  'veh_10088_subway',
#                                                                  'veh_10089_subway',
#                                                                  'veh_10090_subway',
#                                                                  'veh_10091_subway',
#                                                                  'veh_10092_subway',
#                                                                  'veh_10093_subway',
#                                                                  'veh_10094_subway',
#                                                                  'veh_10095_subway',
#                                                                  'veh_10096_subway',
#                                                                  'veh_10097_subway',
#                                                                  'veh_10098_subway',
#                                                                  'veh_10099_subway',
#                                                                  'veh_100_bus',
#                                                                  'veh_10100_subway',
#                                                                  'veh_10101_subway',
#                                                                  'veh_10102_subway',
#                                                                  'veh_10103_subway',
#                                                                  'veh_10104_subway',
#                                                                  'veh_10105_subway',
#                                                                  'veh_10106_subway',
#                                                                  'veh_10107_subway',
#                                                                  'veh_10108_subway',
#                                                                  'veh_10109_subway',
#                                                                  'veh_10110_subway',
#                                                                  'veh_10111_subway',
#                                                                  'veh_10112_subway',
#                                                                  'veh_10113_subway',
#                                                                  'veh_10114_subway',
#                                                                  'veh_10115_subway',
#                                                                  'veh_10116_subway',
#                                                                  'veh_10117_subway',
#                                                                  'veh_10118_subway',
#                                                                  'veh_10119_subway',
#                                                                  'veh_10120_subway',
#                                                                  'veh_10121_subway',
#                                                                  'veh_10122_subway',
#                                                                  'veh_10123_subway',
#                                                                  'veh_10124_subway',
#                                                                  'veh_10125_subway',
#                                                                  'veh_10126_subway',
#                                                                  'veh_10127_subway',
#                                                                  'veh_10128_subway',
#                                                                  'veh_10129_subway',
#                                                                  'veh_10130_subway',
#                                                                  'veh_10131_subway',
#                                                                  'veh_10132_subway',
#                                                                  'veh_10133_subway',
#                                                                  'veh_10134_subway',
#                                                                  'veh_10135_subway',
#                                                                  'veh_10136_subway',
#                                                                  'veh_10137_subway',
#                                                                  'veh_10138_subway',
#                                                                  'veh_10139_subway',
#                                                                  'veh_10140_subway',
#                                                                  'veh_10141_subway',
#                                                                  'veh_10142_subway',
#                                                                  'veh_10143_subway',
#                                                                  'veh_10144_subway',
#                                                                  'veh_10145_subway',
#                                                                  'veh_10146_subway',
#                                                                  'veh_10147_subway',
#                                                                  'veh_10148_subway',
#                                                                  'veh_10149_subway',
#                                                                  'veh_10150_subway',
#                                                                  'veh_10151_subway',
#                                                                  'veh_10152_subway',
#                                                                  'veh_10153_subway',
#                                                                  'veh_10154_subway',
#                                                                  'veh_10155_subway',
#                                                                  'veh_10156_subway',
#                                                                  'veh_10157_subway',
#                                                                  'veh_10158_subway',
#                                                                  'veh_10159_subway',
#                                                                  'veh_10160_subway',
#                                                                  'veh_10161_subway',
#                                                                  'veh_10162_subway',
#                                                                  'veh_10163_subway',
#                                                                  'veh_10164_subway',
#                                                                  'veh_10165_subway',
#                                                                  'veh_10166_subway',
#                                                                  'veh_10167_subway',
#                                                                  'veh_10168_subway',
#                                                                  'veh_10169_subway',
#                                                                  'veh_10170_subway',
#                                                                  'veh_10171_subway',
#                                                                  'veh_10172_subway',
#                                                                  'veh_10173_subway',
#                                                                  'veh_10174_subway',
#                                                                  'veh_10175_subway',
#                                                                  'veh_10176_subway',
#                                                                  'veh_10177_subway',
#                                                                  'veh_10178_subway',
#                                                                  'veh_10179_subway',
#                                                                  'veh_10180_subway',
#                                                                  'veh_10181_subway',
#                                                                  'veh_10182_subway',
#                                                                  'veh_10183_subway',
#                                                                  'veh_10184_subway',
#                                                                  'veh_10185_subway',
#                                                                  'veh_10186_subway',
#                                                                  'veh_10187_subway',
#                                                                  'veh_10188_subway',
#                                                                  'veh_10189_subway',
#                                                                  'veh_10190_subway',
#                                                                  'veh_10191_subway',
#                                                                  'veh_10192_subway',
#                                                                  'veh_10193_subway',
#                                                                  'veh_10194_subway',
#                                                                  'veh_10195_subway',
#                                                                  'veh_10196_subway',
#                                                                  'veh_10197_subway',
#                                                                  'veh_10198_subway',
#                                                                  'veh_10199_subway',
#                                                                  'veh_101_bus',
#                                                                  'veh_10200_subway',
#                                                                  'veh_10201_subway',
#                                                                  'veh_10202_subway',
#                                                                  'veh_10203_subway',
#                                                                  'veh_10204_subway',
#                                                                  'veh_10205_subway',
#                                                                  'veh_10206_subway',
#                                                                  'veh_10207_subway',
#                                                                  'veh_10208_subway',
#                                                                  'veh_10209_subway',
#                                                                  'veh_10210_subway',
#                                                                  'veh_10211_subway',
#                                                                  'veh_10212_subway',
#                                                                  'veh_10213_subway',
#                                                                  'veh_10214_subway',
#                                                                  'veh_10215_subway',
#                                                                  'veh_10216_subway',
#                                                                  'veh_10217_subway',
#                                                                  'veh_10218_subway',
#                                                                  'veh_10219_subway',
#                                                                  'veh_10220_subway',
#                                                                  'veh_10221_subway',
#                                                                  'veh_10222_subway',
#                                                                  'veh_10223_subway',
#                                                                  'veh_10224_subway',
#                                                                  'veh_10225_subway',
#                                                                  'veh_10226_subway',
#                                                                  'veh_10227_subway',
#                                                                  'veh_10228_subway',
#                                                                  'veh_10229_subway',
#                                                                  'veh_10230_subway',
#                                                                  'veh_10231_subway',
#                                                                  'veh_10232_subway',
#                                                                  'veh_10233_subway',
#                                                                  'veh_10234_subway',
#                                                                  'veh_10235_subway',
#                                                                  'veh_10236_subway',
#                                                                  'veh_10237_subway',
#                                                                  'veh_10238_subway',
#                                                                  'veh_10239_subway',
#                                                                  'veh_10240_subway',
#                                                                  'veh_10241_subway',
#                                                                  'veh_10242_subway',
#                                                                  'veh_10243_subway',
#                                                                  'veh_10244_subway',
#                                                                  'veh_10245_subway',
#                                                                  'veh_10246_subway',
#                                                                  'veh_10247_subway',
#                                                                  'veh_10248_subway',
#                                                                  'veh_10249_subway',
#                                                                  'veh_10250_subway',
#                                                                  'veh_10251_subway',
#                                                                  'veh_10252_subway',
#                                                                  'veh_10253_subway',
#                                                                  'veh_10254_subway',
#                                                                  'veh_10255_subway',
#                                                                  'veh_10256_subway',
#                                                                  'veh_10257_subway',
#                                                                  'veh_10258_subway',
#                                                                  'veh_10259_subway',
#                                                                  'veh_10260_subway',
#                                                                  'veh_10261_subway',
#                                                                  'veh_10262_subway',
#                                                                  'veh_10263_subway',
#                                                                  'veh_10264_subway',
#                                                                  'veh_10265_subway',
#                                                                  'veh_10266_subway',
#                                                                  'veh_10267_subway',
#                                                                  'veh_10268_subway',
#                                                                  'veh_10269_subway',
#                                                                  'veh_10270_subway',
#                                                                  'veh_10271_subway',
#                                                                  'veh_10272_subway',
#                                                                  'veh_10273_subway',
#                                                                  'veh_10274_subway',
#                                                                  'veh_10275_subway',
#                                                                  'veh_10276_subway',
#                                                                  'veh_10277_subway',
#                                                                  'veh_10278_subway',
#                                                                  'veh_10279_subway',
#                                                                  'veh_10280_subway',
#                                                                  'veh_10281_subway',
#                                                                  'veh_10282_subway',
#                                                                  'veh_10283_subway',
#                                                                  'veh_10284_subway',
#                                                                  'veh_10285_subway',
#                                                                  'veh_10286_subway',
#                                                                  'veh_10287_subway',
#                                                                  'veh_10288_subway',
#                                                                  'veh_10289_subway',
#                                                                  'veh_10290_subway',
#                                                                  'veh_10291_subway',
#                                                                  'veh_10292_subway',
#                                                                  'veh_10293_subway',
#                                                                  'veh_10294_subway',
#                                                                  'veh_10295_subway',
#                                                                  'veh_10296_subway',
#                                                                  'veh_10297_subway',
#                                                                  'veh_10298_subway',
#                                                                  'veh_10299_subway',
#                                                                  'veh_102_bus',
#                                                                  'veh_10300_subway',
#                                                                  'veh_10301_subway',
#                                                                  'veh_10302_subway',
#                                                                  'veh_10303_subway',
#                                                                  'veh_10304_subway',
#                                                                  'veh_10305_subway',
#                                                                  'veh_10306_subway',
#                                                                  'veh_10307_subway',
#                                                                  'veh_10308_subway',
#                                                                  'veh_10309_subway',
#                                                                  'veh_10310_subway',
#                                                                  'veh_10311_subway',
#                                                                  'veh_10312_subway',
#                                                                  'veh_10313_subway',
#                                                                  'veh_10314_subway',
#                                                                  'veh_10315_subway',
#                                                                  'veh_10316_subway',
#                                                                  'veh_10317_subway',
#                                                                  'veh_10318_subway',
#                                                                  'veh_10319_subway',
#                                                                  'veh_10320_subway',
#                                                                  'veh_10321_subway',
#                                                                  'veh_10322_subway',
#                                                                  'veh_10323_subway',
#                                                                  'veh_10324_subway',
#                                                                  'veh_10325_subway',
#                                                                  'veh_10326_subway',
#                                                                  'veh_10327_subway',
#                                                                  'veh_10328_subway',
#                                                                  'veh_10329_subway',
#                                                                  'veh_10330_subway',
#                                                                  'veh_10331_subway',
#                                                                  'veh_10332_subway',
#                                                                  'veh_10333_subway',
#                                                                  'veh_10334_subway',
#                                                                  'veh_10335_subway',
#                                                                  'veh_10336_subway',
#                                                                  'veh_10337_subway',
#                                                                  'veh_10338_subway',
#                                                                  'veh_10339_subway',
#                                                                  'veh_10340_subway',
#                                                                  'veh_10341_subway',
#                                                                  'veh_10342_subway',
#                                                                  'veh_10343_subway',
#                                                                  'veh_10344_subway',
#                                                                  'veh_10345_subway',
#                                                                  'veh_10346_subway',
#                                                                  'veh_10347_subway',
#                                                                  'veh_10348_subway',
#                                                                  'veh_10349_subway',
#                                                                  'veh_10350_subway',
#                                                                  'veh_10351_subway',
#                                                                  'veh_10352_subway',
#                                                                  'veh_10353_subway',
#                                                                  'veh_10354_subway',
#                                                                  'veh_10355_subway',
#                                                                  'veh_10356_subway',
#                                                                  'veh_10357_subway',
#                                                                  'veh_10358_subway',
#                                                                  'veh_10359_subway',
#                                                                  'veh_10360_subway',
#                                                                  'veh_10361_subway',
#                                                                  'veh_10362_subway',
#                                                                  'veh_10363_subway',
#                                                                  'veh_10364_subway',
#                                                                  'veh_10365_subway',
#                                                                  'veh_10366_subway',
#                                                                  'veh_10367_subway',
#                                                                  'veh_10368_subway',
#                                                                  'veh_10369_subway',
#                                                                  'veh_10370_subway',
#                                                                  'veh_10371_subway',
#                                                                  'veh_10372_subway',
#                                                                  'veh_10373_subway',
#                                                                  'veh_10374_subway',
#                                                                  'veh_10375_subway',
#                                                                  'veh_10376_subway',
#                                                                  'veh_10377_subway',
#                                                                  'veh_10378_subway',
#                                                                  'veh_10379_subway',
#                                                                  'veh_10380_subway',
#                                                                  'veh_10381_subway',
#                                                                  'veh_10382_subway',
#                                                                  'veh_10383_subway',
#                                                                  'veh_10384_subway',
#                                                                  'veh_10385_subway',
#                                                                  'veh_10386_subway',
#                                                                  'veh_10387_subway',
#                                                                  'veh_10388_subway',
#                                                                  'veh_10389_subway',
#                                                                  'veh_10390_subway',
#                                                                  'veh_10391_subway',
#                                                                  'veh_10392_subway',
#                                                                  'veh_10393_subway',
#                                                                  'veh_10394_subway',
#                                                                  'veh_10395_subway',
#                                                                  'veh_10396_subway',
#                                                                  'veh_10397_subway',
#                                                                  'veh_10398_subway',
#                                                                  'veh_10399_subway',
#                                                                  'veh_103_bus',
#                                                                  'veh_10400_subway',
#                                                                  'veh_10401_subway',
#                                                                  'veh_10402_subway',
#                                                                  'veh_10403_subway',
#                                                                  'veh_10404_subway',
#                                                                  'veh_10405_subway',
#                                                                  'veh_10406_subway',
#                                                                  'veh_10407_subway',
#                                                                  'veh_10408_subway',
#                                                                  'veh_10409_subway',
#                                                                  'veh_10410_subway',
#                                                                  'veh_10411_subway',
#                                                                  'veh_10412_subway',
#                                                                  'veh_10413_subway',
#                                                                  'veh_10414_subway',
#                                                                  'veh_10415_subway',
#                                                                  'veh_10416_subway',
#                                                                  'veh_10417_subway',
#                                                                  'veh_10418_subway',
#                                                                  'veh_10419_subway',
#                                                                  'veh_10420_subway',
#                                                                  'veh_10421_subway',
#                                                                  'veh_10422_subway',
#                                                                  'veh_10423_subway',
#                                                                  'veh_10424_subway',
#                                                                  'veh_10425_subway',
#                                                                  'veh_10426_subway',
#                                                                  'veh_10427_subway',
#                                                                  'veh_10428_subway',
#                                                                  'veh_10429_subway',
#                                                                  'veh_10430_subway',
#                                                                  'veh_10431_subway',
#                                                                  'veh_10432_subway',
#                                                                  'veh_10433_subway',
#                                                                  'veh_10434_subway',
#                                                                  'veh_10435_subway',
#                                                                  'veh_10436_subway',
#                                                                  'veh_10437_subway',
#                                                                  'veh_10438_subway',
#                                                                  'veh_10439_subway',
#                                                                  'veh_10440_subway',
#                                                                  'veh_10441_subway',
#                                                                  'veh_10442_subway',
#                                                                  'veh_10443_subway',
#                                                                  'veh_10444_subway',
#                                                                  'veh_10445_subway',
#                                                                  'veh_10446_subway',
#                                                                  'veh_10447_subway',
#                                                                  'veh_10448_subway',
#                                                                  'veh_10449_subway',
#                                                                  'veh_10450_subway',
#                                                                  'veh_10451_subway',
#                                                                  'veh_10452_subway',
#                                                                  'veh_10453_subway',
#                                                                  'veh_10454_subway',
#                                                                  'veh_10455_subway',
#                                                                  'veh_10456_subway',
#                                                                  'veh_10457_subway',
#                                                                  'veh_10458_subway',
#                                                                  'veh_10459_subway',
#                                                                  'veh_10460_subway',
#                                                                  'veh_10461_subway',
#                                                                  'veh_10462_subway',
#                                                                  'veh_10463_subway',
#                                                                  'veh_10464_subway',
#                                                                  'veh_10465_subway',
#                                                                  'veh_10466_subway',
#                                                                  'veh_10467_subway',
#                                                                  'veh_10468_subway',
#                                                                  'veh_10469_subway',
#                                                                  'veh_10470_subway',
#                                                                  'veh_10471_subway',
#                                                                  'veh_10472_subway',
#                                                                  'veh_10473_subway',
#                                                                  'veh_10474_subway',
#                                                                  'veh_10475_subway',
#                                                                  'veh_10476_subway',
#                                                                  'veh_10477_subway',
#                                                                  'veh_10478_subway',
#                                                                  'veh_10479_subway',
#                                                                  'veh_10480_subway',
#                                                                  'veh_10481_subway',
#                                                                  'veh_10482_subway',
#                                                                  'veh_10483_subway',
#                                                                  'veh_10484_subway',
#                                                                  'veh_10485_subway',
#                                                                  'veh_10486_subway',
#                                                                  'veh_10487_subway',
#                                                                  'veh_10488_subway',
#                                                                  'veh_10489_subway',
#                                                                  'veh_10490_subway',
#                                                                  'veh_10491_subway',
#                                                                  'veh_10492_subway',
#                                                                  'veh_10493_subway',
#                                                                  'veh_10494_subway',
#                                                                  'veh_10495_subway',
#                                                                  'veh_10496_subway',
#                                                                  'veh_10497_subway',
#                                                                  'veh_10498_subway',
#                                                                  'veh_10499_subway',
#                                                                  'veh_104_bus',
#                                                                  'veh_10500_subway',
#                                                                  'veh_10501_subway',
#                                                                  'veh_10502_subway',
#                                                                  'veh_10503_subway',
#                                                                  'veh_10504_subway',
#                                                                  'veh_10505_subway',
#                                                                  'veh_10506_subway',
#                                                                  'veh_10507_subway',
#                                                                  'veh_10508_subway',
#                                                                  'veh_10509_subway',
#                                                                  'veh_10510_subway',
#                                                                  'veh_10511_subway',
#                                                                  'veh_10512_subway',
#                                                                  'veh_10513_subway',
#                                                                  'veh_10514_subway',
#                                                                  'veh_10515_subway',
#                                                                  'veh_10516_subway',
#                                                                  'veh_10517_subway',
#                                                                  'veh_10518_subway',
#                                                                  'veh_10519_subway',
#                                                                  'veh_10520_subway',
#                                                                  'veh_10521_subway',
#                                                                  'veh_10522_subway',
#                                                                  'veh_10523_subway',
#                                                                  'veh_10524_subway',
#                                                                  'veh_10525_subway',
#                                                                  'veh_10526_subway',
#                                                                  'veh_10527_subway',
#                                                                  'veh_10528_subway',
#                                                                  'veh_10529_subway',
#                                                                  'veh_10530_subway',
#                                                                  'veh_10531_subway',
#                                                                  'veh_10532_subway',
#                                                                  'veh_10533_subway',
#                                                                  'veh_10534_subway',
#                                                                  'veh_10535_subway',
#                                                                  'veh_10536_subway',
#                                                                  'veh_10537_subway',
#                                                                  'veh_10538_subway',
#                                                                  'veh_10539_subway',
#                                                                  'veh_10540_subway',
#                                                                  'veh_10541_subway',
#                                                                  'veh_10542_subway',
#                                                                  'veh_10543_subway',
#                                                                  'veh_10544_subway',
#                                                                  'veh_10545_subway',
#                                                                  'veh_10546_subway',
#                                                                  'veh_10547_subway',
#                                                                  'veh_10548_subway',
#                                                                  'veh_10549_subway',
#                                                                  'veh_10550_subway',
#                                                                  'veh_10551_subway',
#                                                                  'veh_10552_subway',
#                                                                  'veh_10553_subway',
#                                                                  'veh_10554_subway',
# ...
#                                                                  'veh_9813_subway',
#                                                                  'veh_9814_subway',
#                                                                  'veh_9815_subway',
#                                                                  'veh_9816_subway',
#                                                                  'veh_9817_subway',
#                                                                  'veh_9818_subway',
#                                                                  'veh_9819_subway',
#                                                                  'veh_9820_subway',
#                                                                  'veh_9821_subway',
#                                                                  'veh_9822_subway',
#                                                                  'veh_9823_subway',
#                                                                  'veh_9824_subway',
#                                                                  'veh_9825_subway',
#                                                                  'veh_9826_subway',
#                                                                  'veh_9827_subway',
#                                                                  'veh_9828_subway',
#                                                                  'veh_9829_subway',
#                                                                  'veh_9830_subway',
#                                                                  'veh_9831_subway',
#                                                                  'veh_9832_subway',
#                                                                  'veh_9833_subway',
#                                                                  'veh_9834_subway',
#                                                                  'veh_9835_subway',
#                                                                  'veh_9836_subway',
#                                                                  'veh_9837_subway',
#                                                                  'veh_9838_subway',
#                                                                  'veh_9839_subway',
#                                                                  'veh_9840_subway',
#                                                                  'veh_9841_subway',
#                                                                  'veh_9842_subway',
#                                                                  'veh_9843_subway',
#                                                                  'veh_9844_subway',
#                                                                  'veh_9845_subway',
#                                                                  'veh_9846_subway',
#                                                                  'veh_9847_subway',
#                                                                  'veh_9848_subway',
#                                                                  'veh_9849_subway',
#                                                                  'veh_9850_subway',
#                                                                  'veh_9851_subway',
#                                                                  'veh_9852_subway',
#                                                                  'veh_9853_subway',
#                                                                  'veh_9854_subway',
#                                                                  'veh_9855_subway',
#                                                                  'veh_9856_subway',
#                                                                  'veh_9857_subway',
#                                                                  'veh_9858_subway',
#                                                                  'veh_9859_subway',
#                                                                  'veh_9860_subway',
#                                                                  'veh_9861_subway',
#                                                                  'veh_9862_subway',
#                                                                  'veh_9863_subway',
#                                                                  'veh_9864_subway',
#                                                                  'veh_9865_subway',
#                                                                  'veh_9866_subway',
#                                                                  'veh_9867_subway',
#                                                                  'veh_9868_subway',
#                                                                  'veh_9869_subway',
#                                                                  'veh_9870_subway',
#                                                                  'veh_9871_subway',
#                                                                  'veh_9872_subway',
#                                                                  'veh_9873_subway',
#                                                                  'veh_9874_subway',
#                                                                  'veh_9875_subway',
#                                                                  'veh_9876_subway',
#                                                                  'veh_9877_subway',
#                                                                  'veh_9878_subway',
#                                                                  'veh_9879_subway',
#                                                                  'veh_9880_subway',
#                                                                  'veh_9881_subway',
#                                                                  'veh_9882_subway',
#                                                                  'veh_9883_subway',
#                                                                  'veh_9884_subway',
#                                                                  'veh_9885_subway',
#                                                                  'veh_9886_subway',
#                                                                  'veh_9887_subway',
#                                                                  'veh_9888_subway',
#                                                                  'veh_9889_subway',
#                                                                  'veh_9890_subway',
#                                                                  'veh_9891_subway',
#                                                                  'veh_9892_subway',
#                                                                  'veh_9893_subway',
#                                                                  'veh_9894_subway',
#                                                                  'veh_9895_subway',
#                                                                  'veh_9896_subway',
#                                                                  'veh_9897_subway',
#                                                                  'veh_9898_subway',
#                                                                  'veh_9899_subway',
#                                                                  'veh_98_bus',
#                                                                  'veh_9900_subway',
#                                                                  'veh_9901_subway',
#                                                                  'veh_9902_subway',
#                                                                  'veh_9903_subway',
#                                                                  'veh_9904_subway',
#                                                                  'veh_9905_subway',
#                                                                  'veh_9906_subway',
#                                                                  'veh_9907_subway',
#                                                                  'veh_9908_subway',
#                                                                  'veh_9909_subway',
#                                                                  'veh_9910_subway',
#                                                                  'veh_9911_subway',
#                                                                  'veh_9912_subway',
#                                                                  'veh_9913_subway',
#                                                                  'veh_9914_subway',
#                                                                  'veh_9915_subway',
#                                                                  'veh_9916_subway',
#                                                                  'veh_9917_subway',
#                                                                  'veh_9918_subway',
#                                                                  'veh_9919_subway',
#                                                                  'veh_9920_subway',
#                                                                  'veh_9921_subway',
#                                                                  'veh_9922_subway',
#                                                                  'veh_9923_subway',
#                                                                  'veh_9924_subway',
#                                                                  'veh_9925_subway',
#                                                                  'veh_9926_subway',
#                                                                  'veh_9927_subway',
#                                                                  'veh_9928_subway',
#                                                                  'veh_9929_subway',
#                                                                  'veh_9930_subway',
#                                                                  'veh_9931_subway',
#                                                                  'veh_9932_subway',
#                                                                  'veh_9933_subway',
#                                                                  'veh_9934_subway',
#                                                                  'veh_9935_subway',
#                                                                  'veh_9936_subway',
#                                                                  'veh_9937_subway',
#                                                                  'veh_9938_subway',
#                                                                  'veh_9939_subway',
#                                                                  'veh_9940_subway',
#                                                                  'veh_9941_subway',
#                                                                  'veh_9942_subway',
#                                                                  'veh_9943_subway',
#                                                                  'veh_9944_subway',
#                                                                  'veh_9945_subway',
#                                                                  'veh_9946_subway',
#                                                                  'veh_9947_subway',
#                                                                  'veh_9948_subway',
#                                                                  'veh_9949_subway',
#                                                                  'veh_9950_subway',
#                                                                  'veh_9951_subway',
#                                                                  'veh_9952_subway',
#                                                                  'veh_9953_subway',
#                                                                  'veh_9954_subway',
#                                                                  'veh_9955_subway',
#                                                                  'veh_9956_subway',
#                                                                  'veh_9957_subway',
#                                                                  'veh_9958_subway',
#                                                                  'veh_9959_subway',
#                                                                  'veh_9960_subway',
#                                                                  'veh_9961_subway',
#                                                                  'veh_9962_subway',
#                                                                  'veh_9963_subway',
#                                                                  'veh_9964_subway',
#                                                                  'veh_9965_subway',
#                                                                  'veh_9966_subway',
#                                                                  'veh_9967_subway',
#                                                                  'veh_9968_subway',
#                                                                  'veh_9969_subway',
#                                                                  'veh_9970_subway',
#                                                                  'veh_9971_subway',
#                                                                  'veh_9972_subway',
#                                                                  'veh_9973_subway',
#                                                                  'veh_9974_subway',
#                                                                  'veh_9975_subway',
#                                                                  'veh_9976_subway',
#                                                                  'veh_9977_subway',
#                                                                  'veh_9978_subway',
#                                                                  'veh_9979_subway',
#                                                                  'veh_9980_subway',
#                                                                  'veh_9981_subway',
#                                                                  'veh_9982_subway',
#                                                                  'veh_9983_subway',
#                                                                  'veh_9984_subway',
#                                                                  'veh_9985_subway',
#                                                                  'veh_9986_subway',
#                                                                  'veh_9987_subway',
#                                                                  'veh_9988_subway',
#                                                                  'veh_9989_subway',
#                                                                  'veh_9990_subway',
#                                                                  'veh_9991_subway',
#                                                                  'veh_9992_subway',
#                                                                  'veh_9993_subway',
#                                                                  'veh_9994_subway',
#                                                                  'veh_9995_subway',
#                                                                  'veh_9996_subway',
#                                                                  'veh_9997_subway',
#                                                                  'veh_9998_subway',
#                                                                  'veh_9999_subway',
#                                                                  'veh_99_bus',
#                                                                  'veh_9_bus'}}}

# %% [markdown]
# Finally, the `routing` section describes routing of the transit schedule services onto the network graph.
# - `services_have_routes_in_the_graph`: all routes have network routes and the links they refer to exist in the graph,
# are connected (to nodes of preceding link is the from node of the next link in the chain) and the `modes` saved on the
# link data accept the mode of the route.
# - `service_routes_with_invalid_network_route`: flags routes not satifying the above,
# - `route_to_crow_fly_ratio`: gives ratio of the length of route to crow-fly distance between each of the stops along
# route. If the route is invalid, it will result in 0. If the route has only one stop it will result in
# `'Division by zero'`.

# %%
pprint(report['routing'])
# Out:
# {'route_to_crow_fly_ratio': {'12430': {'VJ06420fdab0dfe5c8e7f2f9504df05cf6289cd7d3': 1.3239965103249995,
#                                        'VJ06cd41dcd58d947097df4a8f33234ef423210154': 1.3239965103249995,
#                                        'VJ0f3c08222de16c2e278be0a1bf0f9ea47370774e': 1.070199597773601,
#                                        'VJ15419796737689e742962a625abcf3fd5b3d58b1': 1.3239965103249995,
#                                        'VJ235c8fca539cf931b3c673f9b056606384aff950': 1.070199597773601,
#                                        'VJ8f9aea7491080b0137d3092706f53dc11f7dba45': 1.070199597773601,
#                                        'VJ948e8caa0f08b9c6bf6330927893942c474b5100': 1.070199597773601,
#                                        'VJ95b4c534d7c903d76ec0340025aa88b81dba3ce4': 1.070199597773601,
#                                        'VJeae6e634f8479e0b6712780d5728f0afca964e64': 1.3239965103249995,
#                                        'VJeb72539d69ddf8e29f1adf74d43953def196ae41': 1.3239965103249995,
#                                        'VJef7f20c3a9bf1419f6401e1e9131fe2c634bcb9a': 1.070199597773601,
#                                        'VJf8e38a73359b6cf743d8e35ee64ef1f7b7914daa': 1.3239965103249995},
#                              '14073': {'VJ24fe211d801738b556a39f815256d7f6bc544ec5': 1.3174100078621478,
#                                        'VJ6cf76a4c03cca468cb6954db7f7aad5ae189df13': 1.4731295976410892,
#                                        'VJ93d8207ae8540b4ff59d47c9ee1ec5689084522d': 1.3174100078621478,
#                                        'VJaa5ee0daec7529d7668c81fe7fac0c4ff545daea': 1.3174100078621478,
#                                        'VJb4309b7a9598539ab9942ea1bcadc60a91b978ba': 1.4731295976410892,
#                                        'VJc8cdbd902dadeebeeb4dbd7332b564ee2e4b00ce': 1.4731295976410892,
#                                        'VJd132b905afc6c0e8e8a994142e301ca5c0f70e22': 1.4731295976410892,
#                                        'VJd9dbeefeca6d74ef2594a17514ebc08ee2d503b2': 1.3174100078621478,
#                                        'VJdbc280077e505b4f8d66586ca51751a125cb4ef0': 1.4731295976410892,
#                                        'VJe18efadf172576fea7989ec1f233f26854c0f66a': 1.4731295976410892,
#                                        'VJe6ba07ef9f19ae40517261ad626bf34dd656491a': 1.3174100078621478,
#                                        'VJe8cffad09738ff7b9698b333e3247918d5c45358': 1.3174100078621478,
#                                        'VJea6046f64f85febf1854290fb8f76e921e3ac96b': 1.3174100078621478,
#                                        'VJf6055fdf9ef0dd6d0500b6c11adcfdd4d10655dc': 1.4731295976410892,
#                                        'VJfc35884fc4f11dc408a209c19f56f3b60f634daf': 1.4731295976410892},
#                              '14134': {'VJ12ba6089dfb2733e29c415a1a0015fef30fd5305': 0.9541214687590465,
#                                        'VJ256e98df611ff48afe737ddc81cbcde82e4e81c8': 0.9541214687590465,
#                                        'VJ26095b8f9f9db92ca2e53d4c086a7dcd82a13be9': 1.0124891304701473,
#                                        'VJ2aba67e3ed98f2ed5f5966c1ac394cbf6d1943d7': 0.9541214687590465,
#                                        'VJ2c87b2a59184888f3175b55bde7b02d024ea8607': 1.0124891304701473,
#                                        'VJ323d02e117552af1565f2ff1273a612655c829c4': 1.0124891304701473,
#                                        'VJ4c6fa387b0d4be94a6c3679b94790b183e2558ca': 1.0124891304701473,
#                                        'VJ4e2b897edf0e7b8a8e3b5516ab43ce56f72c5cff': 0.9541214687590465,
#                                        'VJ4e311a625836374adf4cfaa841224840dbeb7619': 1.0124891304701473,
#                                        'VJ5909ba51575a9459eb0013fbd31c8205455ca2fd': 1.0124891304701473,
#                                        'VJa7f37392e276aeac26c7e73bbc05e6a71af38dba': 0.9541214687590465,
#                                        'VJb93a17a405fe502c5b3a2d6544105b0311da9fe2': 1.0124891304701473,
#                                        'VJd78967364a302cf232c5139d40622dcb6c238c9e': 0.9541214687590465,
#                                        'VJdb0c128567fcbcc063d554ae1c95851cee41b909': 1.0124891304701473,
#                                        'VJdf3936da1a51eb33db594ef99738802c14b19995': 0.9541214687590465,
#                                        'VJf9a22035ae6f25bb420df833474943ad76065c89': 0.9541214687590465},
#                              '15234': {'VJ1a8cc306354fdc322d739ae644eb73444341d08d': 0.6044320988812977,
#                                        'VJ28a8a6a4ab02807a4fdfd199e5c2ca0622d34d0c': 0.6044320988812977,
#                                        'VJ3d50b96792ae8495dbe5a5e372849a60c48b2279': 0.6044320988812977,
#                                        'VJ5b511605b1e07428c2e0a7d676d301c6c40dcca6': 0.6044320988812977,
#                                        'VJ652c769bc42361cc0308dff59a1fdcf0949bdade': 0.6044320988812977,
#                                        'VJ8ccf92aa0f351b2e31f1a078b968dff4c2505c02': 0.6044320988812977,
#                                        'VJ9b58a59e3d74941586a5bca7726a8aa624da67fc': 1.7553459621554637,
#                                        'VJbf9d4fdb976223e6a026c0c669ed290418abefee': 0.6044320988812977,
#                                        'VJd4cbfb092a104ac6a3164a86e9765f68734fdfcf': 0.6044320988812977},
#                              '15660': {'VJ1cf651142378958b52229bfe1fa552e49136e60e': 1.9980716009371184,
#                                        'VJ3716910ec59c370d9f5c69137df7276b68cf0a08': 1.9980716009371184,
#                                        'VJf2e0de4f5dad68cb03064e6064e372dde52cc678': 2.564548846862288},
#                              '17732': {'VJ0cb60de3ed229c1413abac506e770b6ab8a7c49a': 1.0945023219643575,
#                                        'VJ85c23573d670bab5485618b0c5fddff3314efc89': 1.5960855931705888},
#                              '18853': {'VJ8cacca9a6722c497c413005568182ecf4d50b160': 1.4017266705541247,
#                                        'VJf3e316e5e605bb512147dee2a989be5a82ef1b5f': 0.9401483494104607,
#                                        'VJfc4917783c2ca3227789fa7c532c9adf47702095': 1.4017266705541247},
#                              '18915': {'VJ0d304b95d39f4bce48e6ff26ddd73a9c06f17f4f': 1.0945023219643575,
#                                        'VJ520ec0c0ca58a849349fa614b5cf9270ac5c93da': 1.5960855931705888,
#                                        'VJ887921c00645929c5402ac46592e57c368ea63a1': 1.5960855931705888,
#                                        'VJ8a4b1ca7dfd0a130abd1de9f55f3b756617dd4ca': 1.0945023219643575,
#                                        'VJb08f8a2de01a4ef99d3b7fefd9022117ac307531': 1.5960855931705888},
#                              '20274': {'VJ375a660d47a2aa570aa20a8568012da8497ffecf': 0.9400599474266972,
#                                        'VJ6c64ab7b477e201cae950efde5bd0cb4e2e8888e': 1.3888553991046222,
#                                        'VJ812fad65e7fa418645b57b446f00cba573f2cdaf': 1.3888553991046222}},
#  'service_routes_with_invalid_network_route': [],
#  'services_have_routes_in_the_graph': True}

# %% [markdown]
# The above report relies on a lot of convenience methods which can be used on their own. For example, you can list all invalid routes for the network using:

# %%
n.invalid_network_routes()
# Out:
# []

# %%
n.schedule.is_valid_schedule()
# Out:
# True

# %% [markdown]
# Something that is not included in the validity report (because MATSim doesn't insist on it being satified) is strong connectivity of PT. You can call `is_strongly_connected` on `Schedule` or the schedule components: `Service` and `Route`. The process uses an underlying  directed graph of stop connections (which you can access by calling `graph` method on a schedule-type element, e.g. if `s` is a `genet.Service` object, `s.graph()` will give you this directed graph)).

# %%
n.schedule.is_strongly_connected()
# Out:
# False

# %%
n.schedule.graph().is_directed()
# Out:
# True
